# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/datasets/omarshakem/kidney-diseasee-csv/kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age  Blood Pressure  Specific Gravity  Albumin  Sugar Red Blood Cells  \
# 0   0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   1   7.0            50.0             1.020      4.0    0.0             NaN
# 2   2  62.0            80.0             1.010      2.0    3.0          normal
# 3   3  48.0            70.0             1.005      4.0    0.0          normal
# 4   4  51.0            80.0             1.010      2.0    0.0          normal
#
#    Pus Cell Pus Cell Clumps    Bacteria  ...  Packed Cell Volume  \
# 0    normal      notpresent  notpresent  ...                  44
# 1    normal      notpresent  notpresent  ...                  38
# 2    normal      notpresent  notpresent  ...                  31
# 3  abnormal         present  notpresent  ...                  32
# 4    normal      notpresent  notpresent  ...                  35
#
#    White Blood Cell Count  Red Blood Cell Count  Hypertension  \
# ...

# %%
print(df.shape)
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   Blood Pressure           388 non-null    float64
#  3   Specific Gravity         353 non-null    float64
#  4   Albumin                  354 non-null    float64
#  5   Sugar                    351 non-null    float64
#  6   Red Blood Cells          248 non-null    object
#  7   Pus Cell                 335 non-null    object
#  8   Pus Cell Clumps          396 non-null    object
#  9   Bacteria                 396 non-null    object
#  10  Blood Glucose Random     356 non-null    float64
#  11  Blood Urea               381 non-null    float64
#  12  Serum Creatinine         383 non-null    float64
#  13  Sodium                   313 non-null    float64
# ...

# %%
df.describe()
# Out:
#                id         age  Blood Pressure  Specific Gravity     Albumin  \
# count  400.000000  391.000000      388.000000        353.000000  354.000000
# mean   199.500000   51.483376       76.469072          1.017408    1.016949
# std    115.614301   17.169714       13.683637          0.005717    1.352679
# min      0.000000    2.000000       50.000000          1.005000    0.000000
# 25%     99.750000   42.000000       70.000000          1.010000    0.000000
# 50%    199.500000   55.000000       80.000000          1.020000    0.000000
# 75%    299.250000   64.500000       80.000000          1.020000    2.000000
# max    399.000000   90.000000      180.000000          1.025000    5.000000
#
#             Sugar  Blood Glucose Random  Blood Urea  Serum Creatinine  \
# count  351.000000            356.000000  381.000000        383.000000
# mean     0.450142            148.036517   57.425722          3.072454
# std      1.099191             79.281714   50.503006          5.741126
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# age                          9
# Blood Pressure              12
# Specific Gravity            47
# Albumin                     46
# Sugar                       49
# Red Blood Cells            152
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random        44
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          70
# White Blood Cell Count     105
# Red Blood Cell Count       130
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   Blood Pressure           388 non-null    float64
#  3   Specific Gravity         353 non-null    float64
#  4   Albumin                  354 non-null    float64
#  5   Sugar                    351 non-null    float64
#  6   Red Blood Cells          248 non-null    object
#  7   Pus Cell                 335 non-null    object
#  8   Pus Cell Clumps          396 non-null    object
#  9   Bacteria                 396 non-null    object
#  10  Blood Glucose Random     356 non-null    float64
#  11  Blood Urea               381 non-null    float64
#  12  Serum Creatinine         383 non-null    float64
#  13  Sodium                   313 non-null    float64
# ...

# %%
df['Packed Cell Volume']=pd.to_numeric(df['Packed Cell Volume'],errors='coerce')
df['White Blood Cell Count']=pd.to_numeric(df['White Blood Cell Count'],errors='coerce')
df['Red Blood Cell Count']=pd.to_numeric(df['Red Blood Cell Count'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   Blood Pressure           388 non-null    float64
#  3   Specific Gravity         353 non-null    float64
#  4   Albumin                  354 non-null    float64
#  5   Sugar                    351 non-null    float64
#  6   Red Blood Cells          248 non-null    object
#  7   Pus Cell                 335 non-null    object
#  8   Pus Cell Clumps          396 non-null    object
#  9   Bacteria                 396 non-null    object
#  10  Blood Glucose Random     356 non-null    float64
#  11  Blood Urea               381 non-null    float64
#  12  Serum Creatinine         383 non-null    float64
#  13  Sodium                   313 non-null    float64
# ...

# %%
df.drop('id',axis=1, inplace=True)

# %%
df.describe()
# Out:
#               age  Blood Pressure  Specific Gravity     Albumin       Sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        Blood Glucose Random  Blood Urea  Serum Creatinine      Sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# ...

# %%
df['age'].value_counts()
# Out:
# age
# 60.0    19
# 65.0    17
# 50.0    12
# 48.0    12
# 55.0    12
#         ..
# 90.0     1
# 2.0      1
# 78.0     1
# 22.0     1
# 79.0     1
# Name: count, Length: 76, dtype: int64

# %%
df['age'].mode()
# Out:
# 0    60.0
# Name: age, dtype: float64

# %%
df['age'].median()
# Out:
# 55.0

# %%
df.fillna({'age' :df['age'].median()},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure              12
# Specific Gravity            47
# Albumin                     46
# Sugar                       49
# Red Blood Cells            152
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random        44
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Blood Pressure'].value_counts()
# Out:
# Blood Pressure
# 80.0     116
# 70.0     112
# 60.0      71
# 90.0      53
# 100.0     25
# 50.0       5
# 110.0      3
# 140.0      1
# 180.0      1
# 120.0      1
# Name: count, dtype: int64

# %%
df['Blood Pressure'].mode()
# Out:
# 0    80.0
# Name: Blood Pressure, dtype: float64

# %%
df['Blood Pressure'].median()
# Out:
# 80.0

# %%
df.fillna({'Blood Pressure' :df['Blood Pressure'].mode()},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure              12
# Specific Gravity            47
# Albumin                     46
# Sugar                       49
# Red Blood Cells            152
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random        44
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df.fillna({'Blood Pressure' :df['Blood Pressure'].median()},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity            47
# Albumin                     46
# Sugar                       49
# Red Blood Cells            152
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random        44
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Specific Gravity'].value_counts()
# Out:
# Specific Gravity
# 1.020    106
# 1.010     84
# 1.025     81
# 1.015     75
# 1.005      7
# Name: count, dtype: int64

# %%
df["Specific Gravity"] = df["Specific Gravity"].ffill()

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                     46
# Sugar                       49
# Red Blood Cells            152
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random        44
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Red Blood Cells'].value_counts()
# Out:
# Red Blood Cells
# normal      201
# abnormal     47
# Name: count, dtype: int64

# %%
df["Red Blood Cells"] = df["Red Blood Cells"].ffill()

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                     46
# Sugar                       49
# Red Blood Cells              2
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random        44
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Blood Glucose Random'].value_counts()
# Out:
# Blood Glucose Random
# 99.0     10
# 100.0     9
# 93.0      9
# 107.0     8
# 117.0     6
#          ..
# 463.0     1
# 269.0     1
# 116.0     1
# 134.0     1
# 87.0      1
# Name: count, Length: 146, dtype: int64

# %%
df['Blood Glucose Random'].median()
# Out:
# 121.0

# %%
df['Blood Glucose Random'].mode()
# Out:
# 0    99.0
# Name: Blood Glucose Random, dtype: float64

# %%
df.fillna({'Blood Glucose Random' :df['Blood Glucose Random'].median()},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                     46
# Sugar                       49
# Red Blood Cells              2
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random         0
# Blood Urea                  19
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Blood Urea'].value_counts()
# Out:
# Blood Urea
# 46.0     15
# 25.0     13
# 19.0     11
# 40.0     10
# 15.0      9
#          ..
# 93.0      1
# 64.0      1
# 79.0      1
# 215.0     1
# 309.0     1
# Name: count, Length: 118, dtype: int64

# %%
df['Blood Urea'].median()
# Out:
# 42.0

# %%
df.fillna({'Blood Urea' :df['Blood Urea'].median()},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                     46
# Sugar                       49
# Red Blood Cells              2
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine            17
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Serum Creatinine'].value_counts()
# Out:
# Serum Creatinine
# 1.2     40
# 1.1     24
# 0.5     23
# 1.0     23
# 0.7     22
#         ..
# 12.0     1
# 13.4     1
# 15.2     1
# 13.3     1
# 0.4      1
# Name: count, Length: 84, dtype: int64

# %%
df["Serum Creatinine"] = df["Serum Creatinine"].bfill()

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                     46
# Sugar                       49
# Red Blood Cells              2
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df.fillna({'Sugar' :df['Sugar']==2},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                     46
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Albumin'].value_counts()
# Out:
# Albumin
# 0.0    199
# 1.0     44
# 3.0     43
# 2.0     43
# 4.0     24
# 5.0      1
# Name: count, dtype: int64

# %%
df.fillna({'Albumin' :df['Albumin']==3},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                      0
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                    65
# Pus Cell Clumps              4
# Bacteria                     4
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Pus Cell'].value_counts()
# Out:
# Pus Cell
# normal      259
# abnormal     76
# Name: count, dtype: int64

# %%
df.fillna({'Pus Cell' :df['Pus Cell']=='abnormal'},inplace=True)

# %%
df['Pus Cell Clumps'].value_counts()
# Out:
# Pus Cell Clumps
# notpresent    354
# present        42
# Name: count, dtype: int64

# %%
df.fillna({'Pus Cell Clumps' :df['Pus Cell Clumps']=='present'},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                      0
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                     0
# Pus Cell Clumps              0
# Bacteria                     4
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Bacteria'].value_counts()
# Out:
# Bacteria
# notpresent    374
# present        22
# Name: count, dtype: int64

# %%
df.fillna({'Bacteria' :df['Bacteria']=='present'},inplace=True)

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                      0
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                     0
# Pus Cell Clumps              0
# Bacteria                     0
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                      87
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Sodium'].value_counts()
# Out:
# Sodium
# 135.0    40
# 140.0    25
# 141.0    22
# 139.0    21
# 138.0    20
# 142.0    20
# 137.0    19
# 150.0    17
# 136.0    17
# 147.0    13
# 145.0    11
# 132.0    10
# 146.0    10
# 144.0     9
# 131.0     9
# 133.0     8
# 130.0     7
# 134.0     6
# 143.0     4
# 124.0     3
# 127.0     3
# 113.0     2
# 114.0     2
# 120.0     2
# 128.0     2
# 125.0     2
# 122.0     2
# 111.0     1
# 104.0     1
# 129.0     1
# 4.5       1
# 163.0     1
# 126.0     1
# 115.0     1
# Name: count, dtype: int64

# %%
df["Sodium"] = df["Sodium"].ffill()

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                      0
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                     0
# Pus Cell Clumps              0
# Bacteria                     0
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                       3
# Potassium                   88
# Hemoglobin                  52
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Potassium'].value_counts()
# Out:
# Potassium
# 5.0     30
# 3.5     30
# 4.9     27
# 4.7     17
# 4.8     16
# 4.0     14
# 3.9     14
# 4.2     14
# 4.4     14
# 4.1     14
# 3.8     14
# 4.5     13
# 4.3     12
# 3.7     12
# 3.6      8
# 4.6      7
# 3.4      5
# 5.2      5
# 5.7      4
# 5.3      4
# 5.4      3
# 2.9      3
# 3.3      3
# 3.2      3
# 6.3      3
# 5.5      3
# 2.5      2
# 5.8      2
# 3.0      2
# 6.5      2
# 5.9      2
# 5.6      2
# 6.4      1
# 6.6      1
# 39.0     1
# 7.6      1
# 47.0     1
# 5.1      1
# 2.7      1
# 2.8      1
# Name: count, dtype: int64

# %%
df['Potassium'].median()
# Out:
# 4.4

# %%
df.fillna({'Potassium' :df['Potassium'].median()},inplace=True)

# %%
df['Hemoglobin'].value_counts()
# Out:
# Hemoglobin
# 15.0    16
# 10.9     8
# 9.8      7
# 11.1     7
# 13.0     7
#         ..
# 9.0      1
# 17.3     1
# 17.7     1
# 17.5     1
# 17.6     1
# Name: count, Length: 115, dtype: int64

# %%
df["Hemoglobin"] = df["Hemoglobin"].bfill()

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                      0
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                     0
# Pus Cell Clumps              0
# Bacteria                     0
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                       3
# Potassium                    0
# Hemoglobin                   0
# Packed Cell Volume          71
# White Blood Cell Count     106
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Packed Cell Volume'].value_counts()
# Out:
# Packed Cell Volume
# 41.0    21
# 52.0    21
# 44.0    19
# 48.0    19
# 40.0    16
# 43.0    15
# 45.0    13
# 42.0    13
# 33.0    12
# 32.0    12
# 28.0    12
# 36.0    12
# 50.0    12
# 34.0    11
# 37.0    11
# 35.0     9
# 46.0     9
# 29.0     9
# 30.0     9
# 31.0     8
# 24.0     7
# 39.0     7
# 26.0     6
# 38.0     5
# 53.0     4
# 49.0     4
# 54.0     4
# 51.0     4
# 47.0     4
# 25.0     3
# 27.0     3
# 22.0     3
# 19.0     2
# 23.0     2
# 17.0     1
# 18.0     1
# 14.0     1
# 16.0     1
# 21.0     1
# 15.0     1
# 9.0      1
# 20.0     1
# Name: count, dtype: int64

# %%
df["Packed Cell Volume"] = df["Packed Cell Volume"].bfill()

# %%
df['White Blood Cell Count'].value_counts()
# Out:
# White Blood Cell Count
# 9800.0    11
# 6700.0    10
# 9600.0     9
# 9200.0     9
# 7200.0     9
#           ..
# 9900.0     1
# 5900.0     1
# 5200.0     1
# 9700.0     1
# 5100.0     1
# Name: count, Length: 89, dtype: int64

# %%
df["White Blood Cell Count"] = df["White Blood Cell Count"].bfill()

# %%
df.isna().sum()
# Out:
# age                          0
# Blood Pressure               0
# Specific Gravity             0
# Albumin                      0
# Sugar                        0
# Red Blood Cells              2
# Pus Cell                     0
# Pus Cell Clumps              0
# Bacteria                     0
# Blood Glucose Random         0
# Blood Urea                   0
# Serum Creatinine             0
# Sodium                       3
# Potassium                    0
# Hemoglobin                   0
# Packed Cell Volume           0
# White Blood Cell Count       0
# Red Blood Cell Count       131
# Hypertension                 2
# Diabetes Mellitus            2
# Coronary Artery Disease      2
# Appetite                     1
# Pedal Edema                  1
# Anemia                       1
# classification               0
# dtype: int64

# %%
df['Red Blood Cell Count'].value_counts()
# Out:
# Red Blood Cell Count
# 5.2    18
# 4.5    16
# 4.9    14
# 4.7    11
# 3.9    10
# 4.8    10
# 5.0    10
# 4.6     9
# 3.4     9
# 3.7     8
# 6.1     8
# 5.9     8
# 5.5     8
# 5.3     7
# 5.4     7
# 3.8     7
# 5.8     7
# 4.0     6
# 4.3     6
# 5.6     6
# 4.2     6
# 5.7     5
# 6.5     5
# 3.2     5
# 4.4     5
# 6.2     5
# 4.1     5
# 6.4     5
# 5.1     5
# 6.3     4
# 6.0     4
# 3.6     4
# 3.3     3
# 3.0     3
# 3.5     3
# 2.6     2
# 2.8     2
# 2.1     2
# 3.1     2
# 2.7     2
# 2.9     2
# 2.5     2
# 2.3     1
# 8.0     1
# 2.4     1
# Name: count, dtype: int64

# %%
df["Red Blood Cell Count"] = df["Red Blood Cell Count"].ffill()

# %%
df['Hypertension'].value_counts()
# Out:
# Hypertension
# no     251
# yes    147
# Name: count, dtype: int64

# %%
df.fillna({'Potassium' :df['Potassium']=='yes'},inplace=True)

# %%
df['Diabetes Mellitus'].value_counts()
# Out:
# Diabetes Mellitus
# no       258
# yes      134
# \tno       3
# \tyes      2
#  yes       1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# age                        0
# Blood Pressure             0
# Specific Gravity           0
# Albumin                    0
# Sugar                      0
# Red Blood Cells            2
# Pus Cell                   0
# Pus Cell Clumps            0
# Bacteria                   0
# Blood Glucose Random       0
# Blood Urea                 0
# Serum Creatinine           0
# Sodium                     3
# Potassium                  0
# Hemoglobin                 0
# Packed Cell Volume         0
# White Blood Cell Count     0
# Red Blood Cell Count       0
# Hypertension               2
# Diabetes Mellitus          2
# Coronary Artery Disease    2
# Appetite                   1
# Pedal Edema                1
# Anemia                     1
# classification             0
# dtype: int64

# %%
df["Diabetes Mellitus"] = (df["Diabetes Mellitus"]
    .str.strip()
    .str.lower()
)

# %%
df['Diabetes Mellitus'].value_counts()
# Out:
# Diabetes Mellitus
# no     261
# yes    137
# Name: count, dtype: int64

# %%
df.fillna({'Diabetes Mellitus' :df['Diabetes Mellitus']=='yes'},inplace=True)

# %%
df['Coronary Artery Disease'].value_counts()
# Out:
# Coronary Artery Disease
# no      362
# yes      34
# \tno      2
# Name: count, dtype: int64

# %%
df["Coronary Artery Disease"] = (df["Coronary Artery Disease"]
    .str.strip()
    .str.lower()
)

# %%
df.head()
# Out:
#     age  Blood Pressure  Specific Gravity Albumin Sugar Red Blood Cells  \
# 0  48.0            80.0             1.020     1.0   0.0             NaN
# 1   7.0            50.0             1.020     4.0   0.0             NaN
# 2  62.0            80.0             1.010     2.0   3.0          normal
# 3  48.0            70.0             1.005     4.0   0.0          normal
# 4  51.0            80.0             1.010     2.0   0.0          normal
#
#    Pus Cell Pus Cell Clumps    Bacteria  Blood Glucose Random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                 121.0  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    Packed Cell Volume  White Blood Cell Count  Red Blood Cell Count  \
# ...

# %%
df.fillna({'Coronary Artery Disease' :df['Coronary Artery Disease']=='yes'},inplace=True)

# %%
df['Appetite'].value_counts()
# Out:
# Appetite
# good    317
# poor     82
# Name: count, dtype: int64

# %%
df.fillna({'Appetite' :df['Appetite']=='poor'},inplace=True)

# %%
df.isna().sum()
# Out:
# age                        0
# Blood Pressure             0
# Specific Gravity           0
# Albumin                    0
# Sugar                      0
# Red Blood Cells            2
# Pus Cell                   0
# Pus Cell Clumps            0
# Bacteria                   0
# Blood Glucose Random       0
# Blood Urea                 0
# Serum Creatinine           0
# Sodium                     3
# Potassium                  0
# Hemoglobin                 0
# Packed Cell Volume         0
# White Blood Cell Count     0
# Red Blood Cell Count       0
# Hypertension               2
# Diabetes Mellitus          0
# Coronary Artery Disease    0
# Appetite                   0
# Pedal Edema                1
# Anemia                     1
# classification             0
# dtype: int64

# %%
df['Appetite'].value_counts()
# Out:
# Appetite
# good     317
# poor      82
# False      1
# Name: count, dtype: int64

# %%
df["Appetite"] = df["Appetite"].replace({
    False: "poor"})

# %%
df['Appetite'].value_counts()
# Out:
# Appetite
# good    317
# poor     83
# Name: count, dtype: int64

# %%
df['Pedal Edema'].value_counts()
# Out:
# Pedal Edema
# no     323
# yes     76
# Name: count, dtype: int64

# %%
df.fillna({'Pedal Edema' :df['Pedal Edema']=='yes'},inplace=True)

# %%
df['Anemia'].value_counts()
# Out:
# Anemia
# no     339
# yes     60
# Name: count, dtype: int64

# %%
df.fillna({'Anemia' :df['Anemia']=='yes'},inplace=True)

# %%
df.isna().sum()
# Out:
# age                        0
# Blood Pressure             0
# Specific Gravity           0
# Albumin                    0
# Sugar                      0
# Red Blood Cells            2
# Pus Cell                   0
# Pus Cell Clumps            0
# Bacteria                   0
# Blood Glucose Random       0
# Blood Urea                 0
# Serum Creatinine           0
# Sodium                     3
# Potassium                  0
# Hemoglobin                 0
# Packed Cell Volume         0
# White Blood Cell Count     0
# Red Blood Cell Count       0
# Hypertension               2
# Diabetes Mellitus          0
# Coronary Artery Disease    0
# Appetite                   0
# Pedal Edema                0
# Anemia                     0
# classification             0
# dtype: int64

# %%
df['Red Blood Cells'].value_counts()
# Out:
# Red Blood Cells
# normal      289
# abnormal    109
# Name: count, dtype: int64

# %%
df.fillna({'Red Blood Cells' :df['Red Blood Cells']=='abnormal'},inplace=True)

# %%
df['Sodium'].value_counts()
# Out:
# Sodium
# 135.0    51
# 141.0    30
# 140.0    29
# 139.0    26
# 136.0    24
# 137.0    24
# 138.0    23
# 142.0    21
# 150.0    17
# 131.0    15
# 145.0    14
# 147.0    14
# 130.0    14
# 146.0    12
# 133.0    11
# 144.0    10
# 132.0    10
# 134.0     8
# 128.0     7
# 127.0     6
# 125.0     4
# 143.0     4
# 124.0     3
# 113.0     3
# 104.0     3
# 114.0     3
# 111.0     2
# 122.0     2
# 120.0     2
# 129.0     1
# 4.5       1
# 163.0     1
# 126.0     1
# 115.0     1
# Name: count, dtype: int64

# %%
df.fillna({'Sodium' :df['Sodium']==128.0},inplace=True)

# %%
df['Hypertension'].value_counts()
# Out:
# Hypertension
# no     251
# yes    147
# Name: count, dtype: int64

# %%
df.fillna({'Hypertension' :df['Hypertension']=='yes'},inplace=True)

# %%
df.isna().sum()
# Out:
# age                        0
# Blood Pressure             0
# Specific Gravity           0
# Albumin                    0
# Sugar                      0
# Red Blood Cells            0
# Pus Cell                   0
# Pus Cell Clumps            0
# Bacteria                   0
# Blood Glucose Random       0
# Blood Urea                 0
# Serum Creatinine           0
# Sodium                     0
# Potassium                  0
# Hemoglobin                 0
# Packed Cell Volume         0
# White Blood Cell Count     0
# Red Blood Cell Count       0
# Hypertension               0
# Diabetes Mellitus          0
# Coronary Artery Disease    0
# Appetite                   0
# Pedal Edema                0
# Anemia                     0
# classification             0
# dtype: int64

# %%
df.head()
# Out:
#     age  Blood Pressure  Specific Gravity Albumin Sugar Red Blood Cells  \
# 0  48.0            80.0             1.020     1.0   0.0           False
# 1   7.0            50.0             1.020     4.0   0.0           False
# 2  62.0            80.0             1.010     2.0   3.0          normal
# 3  48.0            70.0             1.005     4.0   0.0          normal
# 4  51.0            80.0             1.010     2.0   0.0          normal
#
#    Pus Cell Pus Cell Clumps    Bacteria  Blood Glucose Random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                 121.0  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    Packed Cell Volume  White Blood Cell Count Red Blood Cell Count  \
# ...

# %%
df['Albumin'] = pd.to_numeric(df['Albumin'], errors='coerce')
df = df.dropna(subset=['Albumin'])

# %%
df['Albumin'].value_counts()
# Out:
# Albumin
# 0.0    245
# 1.0     44
# 3.0     43
# 2.0     43
# 4.0     24
# 5.0      1
# Name: count, dtype: int64

# %%
df['classification'] = df['classification'].str.strip()
df.replace('?', pd.NA, inplace=True)

# %%
sns.histplot(df['age'].dropna(), kde=True, color='blue')
plt.title('Distribution of Age')
plt.show()

# %%
sns.histplot(df['Blood Pressure'].dropna(), kde=True, color='red')
plt.title('Distribution of Blood Pressure')
plt.show()

# %%
sns.histplot(df['Blood Glucose Random'].dropna(), kde=True, color='orange')
plt.title('Distribution of Blood Glucose Random')
plt.show()

# %%
sns.countplot(x='Albumin', data=df, palette='viridis')
plt.title('Levels of Albumin')
plt.show()
# Out:
# /tmp/ipykernel_55/1353112604.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Albumin', data=df, palette='viridis')

# %%
sns.countplot(x='Sugar', data=df, palette='magma')
plt.title('Sugar Levels in Urine')
plt.show()
# Out:
# /tmp/ipykernel_55/2306455543.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sugar', data=df, palette='magma')

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Hemoglobin'].dropna(), kde=True, color='blue')
plt.title('Distribution of Hemoglobin Levels')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Anemia', data=df, palette='Set1')
plt.title('Number of Anemia Cases')
plt.show()
# Out:
# /tmp/ipykernel_55/1632725579.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Anemia', data=df, palette='Set1')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Sugar', data=df, palette='viridis')
plt.title('Distribution of Urine Sugar Levels')
plt.show()
# Out:
# /tmp/ipykernel_55/2585811600.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sugar', data=df, palette='viridis')

# %%
plt.figure(figsize=(6,6))
df['classification'].value_counts().plot.pie(autopct='%1.1f%%', colors=['coral', 'lightblue'])
plt.title('Chronic Kidney Disease Status')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='classification', y='Blood Urea', data=df)
plt.title('Comparison of Blood Urea Between Infected and Uninfected Individuals')
plt.yscale('log') 
plt.show()
